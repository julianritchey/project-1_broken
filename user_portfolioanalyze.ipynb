# %%
import yfinance as yf
import pandas as pd
import numpy as np
import holoviews as hv

from PortfolioAnalyzeTool import portfolio_analysis

# %%
start_date = "2010-01-01"
end_date = "2021-12-31"
symbols = ["AAPL", "AMZN","TSLA"]
weights = [0.4, 0.3, 0.3]
index = "^GSPC"

# %%
beta, sharpe_ratios, sharpe_ratios_plot, cumulative_returns_portfolio_plot = portfolio_analysis(symbols, weights, index, start_date, end_date)
# Out:
# [*********************100%***********************]  3 of 3 completed
# [*********************100%***********************]  1 of 1 completed

# %%
print("Portfolio Beta:", beta)
print("Sharpe Ratios:\n", sharpe_ratios)
# Out:
# Portfolio Beta: 1.1
# Sharpe Ratios:
#     Sharpe Ratio      Asset
# 0        0.5750  Portfolio
# 1        0.3119      Index

# %%
sharpe_ratios_plot
# Out:
# :Bars   [Asset]   (Sharpe Ratio)

# %%
cumulative_returns_portfolio_plot
# Out:
# :Overlay
#    .Curve.I  :Curve   [Date]   (Portfolio Returns)
#    .Curve.II :Curve   [Date]   (Index)
