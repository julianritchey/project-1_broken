# %%
import yfinance as yf
import pandas as pd
import hvplot.pandas
import matplotlib.pyplot as plt
import holoviews as hv

from StockAnalyzeTool import calculate_statistics
from StockAnalyzeTool import plot_daily_returns
from StockAnalyzeTool import plot_cumulative_returns
from StockAnalyzeTool import calculate_stock_betas
from StockAnalyzeTool import calculate_sharpe_ratios

# %%
symbols = ['MSFT', 'AAPL', 'TSLA','NVDA']
print(type(symbols))
start_date = '2020-04-01'
end_date = '2023-03-31'

all_data_df = calculate_statistics(symbols, start_date, end_date)

print(all_data_df)
# Out:
# <class 'list'>
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#            Symbol  Close Price  Daily Returns  Cumulative Returns
# Date
# 2020-04-01   MSFT   152.110001            NaN                 NaN
# 2020-04-02   MSFT   155.259995       0.020709            0.020709
# 2020-04-03   MSFT   153.830002      -0.009210            0.011308
# 2020-04-06   MSFT   165.270004       0.074368            0.086516
# 2020-04-07   MSFT   163.490005      -0.010770            0.074814
# ...           ...          ...            ...                 ...
# 2023-03-24   NVDA   267.790009      -0.015152            3.406796
# 2023-03-27   NVDA   265.309998      -0.009261            3.365985
# 2023-03-28   NVDA   264.100006      -0.004561            3.346073
# ...

# %%
daily_returns_plot = plot_daily_returns(all_data_df)
daily_returns_plot
# Out:
# :DynamicMap   [Symbol]
#    :Curve   [Date]   (Daily Returns)

# %%
cumulative_returns_plot = plot_cumulative_returns(all_data_df)
cumulative_returns_plot
# Out:
# :DynamicMap   [Symbol]
#    :Curve   [Date]   (Cumulative Returns)

# %%
beta_df,beta_plot = calculate_stock_betas(symbols, start_date, end_date)
print(beta_df)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#       Beta
# MSFT  1.20
# AAPL  1.26
# TSLA  1.73
# NVDA  1.90

# %%
beta_plot
# Out:
# :Bars   [index]   (Beta)

# %%
sharpe_ratio_df,sharpe_ratio_plot = calculate_sharpe_ratios(symbols, start_date, end_date)
print(sharpe_ratio_df)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#        Sharpe Ratio
# MSFT         0.3369
# Index        0.3677
# AAPL         0.4704
# TSLA         0.4918
# NVDA         0.4830

# %%
sharpe_ratio_plot
# Out:
# :Bars   [index]   (Sharpe Ratio)
